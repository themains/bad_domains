# %%
import pandas as pd
import janitor
import numpy as np
pd.set_option('display.max_columns', 100)
from utilities import pandas_to_tex
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## CPS data

# %%
# https://cps.ipums.org/cps-action/variables/RACE#codes_section
race_codes_cps = {
    100: "White",
    200: "Black",
    300: "American Indian/Aluet/Eskimo",
    650: "Asian or Pacific Islander",
    651: "Asian only",
    652: "Hawaiian/Pacific Islander only",
    700: "Other (single) race, n.e.c.",
    801: "White-Black",
    802: "White-American Indian",
    803: "White-Asian",
    804: "White-Hawaiian/Pacific Islander",
    805: "Black-American Indian",
    806: "Black-Asian",
    807: "Black-Hawaiian/Pacific Islander",
    808: "American Indian-Asian",
    809: "Asian-Hawaiian/Pacific Islander",
    810: "White-Black-American Indian",
    811: "White-Black-Asian",
    812: "White-American Indian-Asian",
    813: "White-Asian-Hawaiian/Pacific Islander",
    814: "White-Black-American Indian-Asian",
    815: "American Indian-Hawaiian/Pacific Islander",
    816: "White-Black-Hawaiian/Pacific Islander",
    817: "White-American Indian-Hawaiian/Pacific Islander",
    818: "Black-American Indian-Asian",
    819: "White-American Indian-Asian-Hawaiian/Pacific Islander",
    820: "Two or three races, unspecified",
    830: "Four or five races, unspecified",
    999: "Blank",
}
race_map = {
    "White": "White",
    "Black": "Black",
    "American Indian/Aluet/Eskimo": "Other",
    "Asian or Pacific Islander": "Asian",
    "Asian only": "Asian",
    "Hawaiian/Pacific Islander only": "Asian",
    "Other (single) race, n.e.c.": "Other",
    "White-Black": "Other",
    "White-American Indian": "Other",
    "White-Asian": "Other",
    "White-Hawaiian/Pacific Islander": "Other",
    "Black-American Indian": "Other",
    "Black-Asian": "Other",
    "Black-Hawaiian/Pacific Islander": "Other",
    "American Indian-Asian": "Other",
    "Asian-Hawaiian/Pacific Islander": "Asian",
    "White-Black-American Indian": "Other",
    "White-Black-Asian": "Other",
    "White-American Indian-Asian": "Other",
    "White-Asian-Hawaiian/Pacific Islander": "Other",
    "White-Black-American Indian-Asian": "Other",
    "American Indian-Hawaiian/Pacific Islander": "Other",
    "White-Black-Hawaiian/Pacific Islander": "Other",
    "White-American Indian-Hawaiian/Pacific Islander": "Other",
    "Black-American Indian-Asian": "Other",
    "White-American Indian-Asian-Hawaiian/Pacific Islander": "Other",
    "Two or three races, unspecified": "Other",
    "Four or five races, unspecified": "Other",
    "Blank": np.nan,
}

# %%
# https://cps.ipums.org/cps-action/variables/HISPAN#codes_section
hispanic_codes_cps = {
    0: "Not Hispanic",
    100: "Mexican",
    102: "Mexican American",
    103: "Mexicano/Mexicana",
    104: "Chicano/Chicana",
    108: "Mexican (Mexicano)",
    109: "Mexicano/Chicano",
    200: "Puerto Rican",
    300: "Cuban",
    400: "Dominican",
    500: "Salvadoran",
    600: "Other Hispanic",
    610: "Central/South American",
    611: "Central American (excluding Salvadoran)",
    612: "South American",
    901: "Do not know",
    902: "Not available/no response"
}

hispanic_mapping = {
    0: "Non-Hispanic",  # Not Hispanic
    100: "Hispanic",
    102: "Hispanic",
    103: "Hispanic",
    104: "Hispanic",
    108: "Hispanic",
    109: "Hispanic",
    200: "Hispanic",
    300: "Hispanic",
    400: "Hispanic",
    500: "Hispanic",
    600: "Hispanic",
    610: "Hispanic",
    611: "Hispanic",
    612: "Hispanic",
    901: None,  # Do not know
    902: None   # Not available/no response
}

# %%
# https://cps.ipums.org/cps-action/variables/EDUC#codes_section
education_mapping = {
    # HS or Below
    0: "HS or Below", 1: "HS or Below", 2: "HS or Below", 
    10: "HS or Below", 11: "HS or Below", 12: "HS or Below",
    13: "HS or Below", 14: "HS or Below", 20: "HS or Below",
    21: "HS or Below", 22: "HS or Below", 30: "HS or Below",
    31: "HS or Below", 32: "HS or Below", 40: "HS or Below",
    50: "HS or Below", 60: "HS or Below", 70: "HS or Below",
    71: "HS or Below", 72: "HS or Below", 73: "HS or Below",
    # Some college
    80: "Some college", 81: "Some college", 
    90: "Some college", 91: "Some college", 92: "Some college",
    # College
    100: "College", 110: "College", 111: "College",
    # Postgrad
    120: "Postgrad", 121: "Postgrad", 122: "Postgrad", 
    123: "Postgrad", 124: "Postgrad", 125: "Postgrad",
    # Missing
    999: None,
}

# %%
age_bins = [-1, 17, 25, 34, 49, 64, float('inf')]
age_labels = ["<18", "18--24", "25--34", "35--49", "50--64", "65+"]

# %%
region_codes_cps = {
    11: "Northeast",
    12: "Northeast",
    21: "Midwest",
    22: "Midwest",
    31: "South",
    32: "South",
    33: "South",
    41: "West",
    42: "West",
    97: "Unknown"
}

# %%
df_cps = (
    pd.read_csv("../data/cps_00002.csv.gz")
    .clean_names()
    .assign(
        race_lab_cps=lambda df_: df_["race"].replace(race_codes_cps),
        race_lab_nohisp=lambda df_: df_["race_lab_cps"].replace(race_map),
        hispanic_lab=lambda df_: df_["hispan"].replace(hispanic_codes_cps),
        race_lab=lambda df_: np.where(df_["hispanic_lab"]=="Not Hispanic", df_["race_lab_nohisp"], "Hispanic"),
        educ_lab=lambda df_: df_["educ"].replace(education_mapping),
        agegroup_lab=lambda df_: pd.cut(df_['age'], bins=age_bins, labels=age_labels),
        # https://cps.ipums.org/cps-action/variables/SEX#codes_section
        gender_lab=lambda df_: df_["sex"].map({1: "Male", 2: "Female"}),
        # https://cps.ipums.org/cps-action/variables/VOTED#codes_section
        voted_lab=lambda df_: np.where(df_["voted"]==2, "Voted", "Did not vote/NA"),
#         voted_lab=np.nan,
        region_lab=lambda df_: df_["region"].replace(region_codes_cps),
    )
    .query("agegroup_lab!='<18'")
)
display(df_cps.head())
df_cps.info()
# Out:
#    year  serial  month    hwtfinl           cpsid  asecflag  asecwth  region  \
# 0  2022       2      1  1662.5757  20210100000400       NaN      NaN      32
# 1  2022       2      1  1662.5757  20210100000400       NaN      NaN      32
# 4  2022       3      1  2037.9611  20220100000300       NaN      NaN      32
# 6  2022       3      1  2037.9611  20220100000300       NaN      NaN      32
# 7  2022       4      1  2094.5077  20211200000200       NaN      NaN      32
#
#    pernum     wtfinl           cpsidv          cpsidp  asecwt  age  sex  race  \
# 0       1  1662.5757  202101000004011  20210100000401     NaN   36    2   100
# 1       2  1978.1985  202101000004021  20210100000402     NaN   41    1   100
# 4       1  2037.9611  202201000003011  20220100000301     NaN   50    2   200
# 6       3  2500.9415  202201000003031  20220100000303     NaN   27    1   200
# 7       1  2094.5077  202112000002011  20211200000201     NaN   38    1   200
#
#    hispan  educ  voted race_lab_cps race_lab_nohisp  hispanic_lab race_lab  \
# 0       0   111    NaN        White           White  Not Hispanic    White
# 1       0   123    NaN        White           White  Not Hispanic    White
# 4       0    81    NaN        Black           Black  Not Hispanic    Black
# 6       0    73    NaN        Black           Black  Not Hispanic    Black
# 7       0   111    NaN        Black           Black  Not Hispanic    Black
#
#        educ_lab agegroup_lab gender_lab        voted_lab region_lab
# 0       College       35--49     Female  Did not vote/NA      South
# 1      Postgrad       35--49       Male  Did not vote/NA      South
# 4  Some college       50--64     Female  Did not vote/NA      South
# 6   HS or Below       25--34       Male  Did not vote/NA      South
# 7       College       35--49       Male  Did not vote/NA      South
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1079085 entries, 0 to 1375634
# Data columns (total 28 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   year             1079085 non-null  int64
#  1   serial           1079085 non-null  int64
#  2   month            1079085 non-null  int64
#  3   hwtfinl          964927 non-null   float64
#  4   cpsid            1079085 non-null  int64
#  5   asecflag         193374 non-null   float64
#  6   asecwth          114158 non-null   float64
#  7   region           1079085 non-null  int64
#  8   pernum           1079085 non-null  int64
#  9   wtfinl           964927 non-null   float64
#  10  cpsidv           1079085 non-null  int64
#  11  cpsidp           1079085 non-null  int64
#  12  asecwt           114158 non-null   float64
#  13  age              1079085 non-null  int64
#  14  sex              1079085 non-null  int64
#  15  race             1079085 non-null  int64
#  16  hispan           1079085 non-null  int64
#  17  educ             1079085 non-null  int64
#  18  voted            78916 non-null    float64
#  19  race_lab_cps     1079085 non-null  object
#  20  race_lab_nohisp  1079085 non-null  object
#  21  hispanic_lab     1079085 non-null  object
#  22  race_lab         1079085 non-null  object
#  23  educ_lab         1079085 non-null  object
#  24  agegroup_lab     1079085 non-null  category
#  25  gender_lab       1079085 non-null  object
#  26  voted_lab        1079085 non-null  object
#  27  region_lab       1079085 non-null  object
# dtypes: category(1), float64(6), int64(13), object(8)
# memory usage: 231.5+ MB

# %% [markdown]
# ## YouGov

# %%
region_codes_yougov = {
    1: "Northeast",
    2: "Midwest",
    3: "South",
    4: "West",
    -1: np.nan
}
voting_mapping_yougov = {
    -1: "Did not vote/NA",  # No Data
    1: "Voted",       # Joe Biden
    2: "Voted",       # Donald Trump
    3: "Voted",       # Jo Jorgensen
    4: "Voted",       # Howie Hawkins
    5: "Voted",       # Other
    6: "Did not vote/NA"    # Did not vote for President
}

# %%
agegroup_yg = {
    "65+": "65+",
    "50--65": "50--64",
    "35--50": "35--49",
    "25--35": "25--34",
    "<25": "18--24",
}
df_yougov = (
    pd.read_csv("../data/ind_data.csv")
    .assign(
        region_lab=lambda df_: df_["region"].replace(region_codes_yougov),
        voted_lab=lambda df_: df_["presvote20post"].map(voting_mapping_yougov),
        agegroup_lab=lambda df_: df_["agegroup_lab"].map(agegroup_yg),
        age=lambda df_: 2022-df_["birthyr"],
    )
)
df_yougov.head()
# Out:
#    caseid  duration  visits  duration_min  duration_hr  harmless  malicious  \
# 0   47541    263115   17194          4385           73     37198         19
# 1   56565    187793   11479          3129           52     22541         10
# 2  203271     94510    6540          1575           26     10298          8
# 3  216457     52109    1770           868           14      3295          1
# 4  257495    188945   10012          3149           52     19151         33
#
#    suspicious  undetected  timeout  malicious_bool  malicious_visits  \
# 0           5       11033        0               2                 4
# 1           3        6576        0               0                 0
# 2           2        2943        0               0                 0
# 3           0         971        0               0                 0
# 4           6        5589        0               4                19
#
#    malicious_min  malicious_hr  suspicious_bool  birthyr  gender  race  educ  \
# 0              0             0                5   1955.0       2     1     2
# 1              0             0                3   1940.0       2     1     3
# 2              0             0                2   1980.0       2     1     6
# 3              0             0                0   1976.0       2     1     2
# 4              2             0                6   1952.0       2     7     1
#
#    pid3  pid7  presvote20post  inputstate  region gender_lab race_lab  \
# 0     2     6               2          12       3     Female    White
# 1     3     5               2          17       2     Female    White
# 2     1     2              -1          54       3     Female    White
# 3     2     7               2          27       2     Female    White
# 4     1     1               1          15       4     Female    Other
#
#        educ_lab agegroup_lab region_lab        voted_lab   age
# 0   HS or Below          65+      South            Voted  67.0
# 1  Some college          65+    Midwest            Voted  82.0
# 2      Postgrad       35--49      South  Did not vote/NA  42.0
# 3   HS or Below       35--49    Midwest            Voted  46.0
# 4   HS or Below          65+       West            Voted  70.0

# %% [markdown]
# ## Compare

# %%
# import pandas as pd

# # Define a function to summarize field distributions
# def summarize_sample(df, fields):
#     summary = {}
#     for field in fields:
#         summary[field] = df[field].value_counts(normalize=True).reset_index()
#         summary[field].columns = [field, 'Proportion']
#     return summary

# # Fields to compare
# fields_to_compare = ['gender_lab', 'race_lab', 'educ_lab', 'agegroup_lab', 'region_lab']

# # Summarize both datasets
# summary_cps = summarize_sample(df_cps, fields_to_compare)
# summary_yougov = summarize_sample(df_yougov, fields_to_compare)

# # Combine summaries for comparison
# comparison = {}
# for field in fields_to_compare:
#     comparison[field] = pd.merge(
#         summary_cps[field],
#         summary_yougov[field],
#         on=field,
#         how='outer',
#         suffixes=('_CPS', '_YouGov')
#     ).fillna(0)

# # Display the comparison tables for each field
# for field, table in comparison.items():
#     print(f"--- {field} ---")
#     print(table)
#     print()

# %%
# var = "gender_lab"

# _dfyg = (
#     df_yougov[var]
#     .value_counts(normalize=True)
#     .reset_index()
#     .rename_column(var, "yougov")
# )
# _dfcps = (
#     df_cps[var]
#     .value_counts(normalize=True)
#     .reset_index()
#     .rename_column(var, "cps")
# )
# _dfsumm = (
#     _dfyg
#     .merge(_dfcps, on="index", validate="1:1")
# )
# _dfsumm

# %%
catvars = ["gender_lab", "race_lab", "educ_lab", "agegroup_lab", "region_lab",]
agegroup_order = ["<18", "18--24", "25--34", "35--49", "50--64", "65+"]
region_order = ["West", "Midwest", "Northeast", "South"]

for var in catvars:
    _dfyg = (
        df_yougov[var]
        .value_counts(normalize=True)
        .reset_index()
        .rename_column(var, "yougov")
    )
    _dfcps = (
        df_cps[var]
        .value_counts(normalize=True)
        .reset_index()
        .rename_column(var, "cps")
    )
    _dfsumm = (
        _dfyg
        .merge(_dfcps, on="index", validate="1:1")
        .round(3)
    )
    
    # reorder agegroup
    if var == "agegroup_lab":
        _dfsumm["index"] = (
            pd.Categorical(
                _dfsumm["index"], categories=agegroup_order, ordered=True)
        )
        _dfsumm = _dfsumm.sort_values("index")
    
    # reorder regions    
    if var == "region_lab":
        _dfsumm["index"] = pd.Categorical(
            _dfsumm["index"], categories=region_order, ordered=True
        )
        _dfsumm = _dfsumm.sort_values("index")
        _dfsumm["index"] = _dfsumm["index"].apply(lambda x: x + " region")
        
    if var=="educ_lab":
#         _dfsumm["ed"]
        _dfsumm.loc[_dfsumm['index'] == 'Postgrad', 'index'] = 'Postgraduate degree'
        _dfsumm.loc[_dfsumm['index'] == 'HS or Below', 'index'] = 'High school or below'
        _dfsumm.loc[_dfsumm['index'] == 'College', 'index'] = 'College degree'

    pandas_to_tex(_dfsumm, f"../tabs/yg_cps_{var}")
    display(_dfsumm)
# Out:
#     index  yougov   cps
# 0  Female   0.525  0.52
# 1    Male   0.475  0.48
#       index  yougov    cps
# 0     White   0.635  0.673
# 1  Hispanic   0.148  0.141
# 2     Black   0.127  0.099
# 3     Other   0.049  0.023
# 4     Asian   0.041  0.064
#                   index  yougov    cps
# 0  High school or below   0.362  0.382
# 1          Some college   0.287  0.267
# 2        College degree   0.225  0.219
# 3   Postgraduate degree   0.125  0.132
#     index  yougov    cps
# 4  18--24   0.094  0.112
# 3  25--34   0.177  0.143
# 0  35--49   0.257  0.240
# 1  50--64   0.247  0.248
# 2     65+   0.226  0.257
#               index  yougov    cps
# 1       West region   0.202  0.274
# 2    Midwest region   0.200  0.193
# 3  Northeast region   0.178  0.161
# 0      South region   0.421  0.371

# %%
var = "age"
mean_yougov = df_yougov[var].mean()
mean_cps = df_cps[var].mean()

_dfsumm = (
    pd.DataFrame({"var": ["Age (mean)"], "yougov": mean_yougov, "cps": mean_cps})
    .round(1)
)
pandas_to_tex(_dfsumm, "../tabs/yg_cps_agemean")
_dfsumm
# Out:
#           var  yougov   cps
# 0  Age (mean)    48.6  49.8

# %% [markdown]
# ## Nationscape

# %%
# https://www.voterstudygroup.org/downloads/nationscape?key=1015588
race_mapping_ns = {
    "Black, or African American": "Black",
    "White": "White",
    "Asian (Filipino)": "Asian",
    "Asian (Vietnamese)": "Asian",
    "Asian (Asian Indian)": "Asian",
    "Asian (Korean)": "Asian",
    "Pacific Islander (Other)": "Other",
    "Pacific Islander (Native Hawaiian)": "Other",
    "Pacific Islander (Guamanian)": "Other",
    "American Indian or Alaska Native": "Other",
    "Some other race": "Other",
    "Asian (Chinese)": "Asian",
    "Asian (Japanese)": "Asian"
}
education_mapping_ns = {
    "3rd Grade or less": "HS or Below",
    "Middle School - Grades 4 - 8": "HS or Below",
    "Completed some high school": "HS or Below",
    "High school graduate": "HS or Below",
    "Completed some college, but no degree": "Some college",
    "Associate Degree": "Some college",
    "Other post high school vocational training": "Some college",
    "College Degree (such as B.A., B.S.)": "College",
    "Completed some graduate, but no degree": "Postgrad",
    "Masters degree": "Postgrad",
    "Doctorate degree": "Postgrad"
}

# %%
vote_2020_mapping_ns = {
    "Joe Biden": "Voted",
    "Donald Trump": "Voted",
    "Someone else": "Voted",
    "I abstained": "Did not vote/NA",
    "I don't recall": "Did not vote/NA",
    "Not Asked": "Did not vote/NA",
    None: "Did not vote/NA"  # Handle NaN or missing values
}

# %%
df_ns = (
    pd.read_stata("../data/Nationscape-Weekly-Materials-DTA-2021Dec/phase_3_v20210301/ns20210112/ns20210112.dta")
    .assign(
        race_lab_nohisp=lambda df_: df_["race_ethnicity"].map(race_mapping_ns),
        race_lab=lambda df_: np.where(df_["hispanic"]=="Not Hispanic", df_["race_lab_nohisp"], "Hispanic"),
        gender_lab=lambda df_: df_["gender"],
        educ_lab=lambda df_: df_["education"].map(education_mapping_ns),
        agegroup_lab=lambda df_: pd.cut(df_['age'], bins=age_bins, labels=age_labels),
        region_lab=lambda df_: df_["census_region"],
        voted_lab=lambda df_: df_["vote_2020_retro"].map(vote_2020_mapping_ns),
    )
)
display(df_ns.head())
df_ns.info(verbose=True)
# Out:
#   response_id          start_date                              right_track  \
# 0    07700007 2021-01-12 10:52:22                   Off on the wrong track
# 1    07700008 2021-01-12 10:55:11  Generally headed in the right direction
# 2    07700009 2021-01-12 10:50:00                   Off on the wrong track
# 3    07700010 2021-01-12 10:47:32                   Off on the wrong track
# 4    07700011 2021-01-12 10:52:57                   Off on the wrong track
#
#    economy_better           interest registration news_sources_facebook  \
# 0          Better   Most of the time   Registered                   Yes
# 1          Better                NaN   Registered                   Yes
# 2  About the same   Some of the time   Registered                   Yes
# 3  About the same   Most of the time   Registered                    No
# 4           Worse  Only now and then   Don't know                    No
#
#   news_sources_cnn news_sources_msnbc news_sources_fox news_sources_network  \
# 0               No                Yes               No                  Yes
# 1              Yes                Yes              Yes                  Yes
# 2               No                 No              Yes                  Yes
# 3              Yes                Yes               No                  Yes
# 4               No                 No               No                  Yes
#
#   news_sources_localtv news_sources_telemundo news_sources_npr  \
# 0                   No                    Yes               No
# 1                  Yes                    Yes              Yes
# 2                  Yes                     No               No
# 3                  Yes                     No               No
# 4                  Yes                     No               No
#
#   news_sources_amtalk news_sources_new_york_times  \
# 0                 Yes                          No
# 1                 Yes                         Yes
# 2                 Yes                          No
# 3                  No                          No
# 4                  No                          No
#
#   news_sources_local_newspaper news_sources_other news_sources_other_TEXT  \
# 0                          Yes                Yes
# 1                          Yes                 No                 Nothing
# 2                           No                 No
# 3                           No                 No
# 4                           No                 No
#
#          pres_approval                       vote_2016 vote_2016_other_text  \
# 0  Strongly disapprove                    Don't recall
# 1     Strongly approve                    Donald Trump
# 2     Strongly approve        Was not eligible to vote
# 3     Somewhat approve                    Donald Trump
# 4  Strongly disapprove  Did not vote, but was eligible
#
#                   vote_intention_retro vote_2020_retro  \
# 0                         Yes, I voted       Joe Biden
# 1                         Yes, I voted    Donald Trump
# 2                         Yes, I voted    Donald Trump
# 3                         Yes, I voted    Donald Trump
# 4  No, I was eligible but did not vote       Not Asked
#
#   vote_2020_retro_other_text       who_won who_won_other_text  \
# 0                                Joe Biden
# 1                             Donald Trump
# 2                             Donald Trump
# 3                                Joe Biden
# 4                                Joe Biden
#
#              primary_party_retro group_favorability_whites  \
# 0  The Democratic Primary/Caucus          Very unfavorable
# 1  The Republican Primary/Caucus            Very favorable
# 2  The Republican Primary/Caucus            Very favorable
# 3                        Neither        Somewhat favorable
# 4                        Neither      Haven't heard enough
#
#   group_favorability_blacks group_favorability_latinos  \
# 0      Haven't heard enough           Very unfavorable
# 1            Very favorable             Very favorable
# 2        Somewhat favorable             Very favorable
# 3        Somewhat favorable         Somewhat favorable
# 4        Somewhat favorable       Haven't heard enough
#
#   group_favorability_asians group_favorability_evangelicals  \
# 0          Very unfavorable                Very unfavorable
# 1      Somewhat unfavorable              Somewhat favorable
# 2            Very favorable                  Very favorable
# 3        Somewhat favorable            Haven't heard enough
# 4      Somewhat unfavorable            Haven't heard enough
#
#   group_favorability_socialists group_favorability_muslims  \
# 0              Very unfavorable           Very unfavorable
# 1                Very favorable             Very favorable
# 2          Somewhat unfavorable             Very favorable
# 3              Very unfavorable         Somewhat favorable
# 4            Somewhat favorable           Very unfavorable
#
#   group_favorability_labor_unions group_favorability_the_police  \
# 0                Very unfavorable          Haven't heard enough
# 1                  Very favorable                Very favorable
# 2                  Very favorable                Very favorable
# 3            Haven't heard enough          Haven't heard enough
# 4            Haven't heard enough          Haven't heard enough
#
#   group_favorability_undocumented group_favorability_lgbt  \
# 0                Very unfavorable    Haven't heard enough
# 1                  Very favorable          Very favorable
# 2              Somewhat favorable          Very favorable
# 3                Very unfavorable      Somewhat favorable
# 4                Very unfavorable    Haven't heard enough
#
#   group_favorability_republicans group_favorability_democrats  \
# 0               Very unfavorable         Haven't heard enough
# 1           Somewhat unfavorable               Very favorable
# 2                 Very favorable         Somewhat unfavorable
# 3             Somewhat favorable           Somewhat favorable
# 4             Somewhat favorable               Very favorable
#
#   group_favorability_white_men group_favorability_jews group_favorability_blm  \
# 0             Very unfavorable    Haven't heard enough   Haven't heard enough
# 1               Very favorable          Very favorable         Very favorable
# 2               Very favorable          Very favorable       Very unfavorable
# 3           Somewhat favorable      Somewhat favorable       Very unfavorable
# 4           Somewhat favorable          Very favorable       Very unfavorable
#
#   group_favorability_trump_s group_favorability_biden_s  \
# 0           Very unfavorable       Haven't heard enough
# 1             Very favorable       Somewhat unfavorable
# 2             Very favorable       Somewhat unfavorable
# 3         Somewhat favorable       Somewhat unfavorable
# 4       Somewhat unfavorable             Very favorable
#
#   cand_favorability_trump cand_favorability_obama cand_favorability_biden  \
# 0    Somewhat unfavorable          Very favorable    Haven't heard enough
# 1      Somewhat favorable    Somewhat unfavorable          Very favorable
# 2          Very favorable    Somewhat unfavorable      Somewhat favorable
# 3      Somewhat favorable        Very unfavorable        Very unfavorable
# 4    Somewhat unfavorable    Somewhat unfavorable          Very favorable
#
#   cand_favorability_harris  ... statements_confront_china  \
# 0       Somewhat favorable  ...            Somewhat Agree
# 1     Somewhat unfavorable  ...                 Not Asked
# 2     Somewhat unfavorable  ...                 Not Asked
# 3         Very unfavorable  ...         Somewhat Disagree
# 4           Very favorable  ...                 Not Asked
#
#   statements_foreign_interests elect_conf_conduct_retro elect_conf_vote_retro  \
# 0            Somewhat Disagree           Very confident    Somewhat confident
# 1                    Not Asked           Very confident        Very confident
# 2            Somewhat Disagree     Not at all confident     Not too confident
# 3            Somewhat Disagree       Somewhat confident    Somewhat confident
# 4                    Not Asked       Somewhat confident  Not at all confident
#
#                                 extra_vote_mail_retr extra_vacc_flu  \
# 0                    Voted on Election Day in-person            0.0
# 1                    Voted on Election Day in-person          100.0
# 2  Received my ballot through the mail and return...          100.0
# 3  Received my ballot through the mail and return...          100.0
# 4                                          Not Asked           50.0
#
#   extra_vacc_covid extra_dem_violence extra_ind_violence extra_rep_violence  \
# 0              0.0         Not at all          Not Asked          Not Asked
# 1            100.0          Not Asked          Not Asked              A lot
# 2             50.0          Not Asked          Not Asked         Not at all
# 3            100.0          Not Asked          Not Asked         Not at all
# 4             10.0          Not Asked         Not at all          Not Asked
#
#   extra_corona_concern extra_sick_you extra_sick_family extra_sick_work  \
# 0   Somewhat concerned             No                No              No
# 1       Very concerned            Yes               Yes             Yes
# 2       Very concerned             No               Yes              No
# 3       Very concerned             No                No              No
# 4       Very concerned             No               Yes              No
#
#   extra_sick_other extra_covid_worn_mask extra_covid_socialize_distance  \
# 0               No                   Yes                             No
# 1              Yes                   Yes                            Yes
# 2              Yes                   Yes                            Yes
# 3              Yes                   Yes                             No
# 4              Yes                   Yes                             No
#
#   extra_covid_socialize_no_dist   extra_trump_corona     extra_gub_corona  \
# 0                           Yes  Strongly disapprove  Strongly disapprove
# 1                           Yes     Strongly approve     Strongly approve
# 2                            No     Somewhat approve     Somewhat approve
# 3                            No     Somewhat approve     Somewhat approve
# 4                            No             Not sure     Somewhat approve
#
#   extra_covid_cancel_meet extra_covid_close_business  \
# 0              Don't know            Strongly oppose
# 1        Strongly support           Strongly support
# 2        Strongly support           Strongly support
# 3        Somewhat support           Somewhat support
# 4         Strongly oppose            Somewhat oppose
#
#   extra_covid_close_schools extra_covid_work_home extra_covid_restrict_home  \
# 0           Strongly oppose      Strongly support           Somewhat oppose
# 1          Strongly support      Strongly support          Strongly support
# 2           Somewhat oppose      Strongly support          Strongly support
# 3          Somewhat support      Somewhat support          Somewhat support
# 4          Strongly support            Don't know           Strongly oppose
#
#   extra_covid_testing extra_covid_require_mask capitol_approval  \
# 0    Somewhat support          Somewhat oppose       Disapprove
# 1    Strongly support         Strongly support          Approve
# 2    Strongly support         Strongly support       Disapprove
# 3    Somewhat support         Somewhat support       Disapprove
# 4     Somewhat oppose               Don't know       Disapprove
#
#   capitol_trump_approv capitol_trump_more                      twitter_ban  \
# 0           Disapprove                Yes                 Somewhat worried
# 1              Approve                Yes                     Very worried
# 2             Not sure           Not sure                     Very worried
# 3              Approve                Yes                 Somewhat worried
# 4           Disapprove           Not sure  Haven't thought much about this
#
#   age  gender census_region      hispanic              race_ethnicity  \
# 0  20  Female         South  Not Hispanic  Black, or African American
# 1  59    Male       Midwest       Mexican  Black, or African American
# 2  21  Female          West  Not Hispanic                       White
# 3  68  Female       Midwest  Not Hispanic                       White
# 4  46  Female         South  Not Hispanic                       White
#
#        household_income                              education state  \
# 0    $75,000 to $79,999                   High school graduate    NC
# 1  $150,000 to $174,999    College Degree (such as B.A., B.S.)    MI
# 2  $100,000 to $124,999                       Associate Degree    UT
# 3    $80,000 to $84,999  Completed some college, but no degree    IA
# 4    $15,000 to $19,999                   High school graduate    VA
#
#   congress_district    weight weight_2020 weight_both race_lab_nohisp  \
# 0              NC02  2.170623    0.768520    1.577373           Black
# 1              MI06  3.612443    4.039212    3.223077           Black
# 2              UT02  5.011087    3.066427    5.010591           White
# 3              IA01  0.968854    1.306608    1.041669           White
# 4              VA04  0.172510    0.169041    0.169441           White
#
#    race_lab gender_lab      educ_lab agegroup_lab region_lab        voted_lab
# 0     Black     Female   HS or Below       18--24      South            Voted
# 1  Hispanic       Male       College       50--64    Midwest            Voted
# 2     White     Female  Some college       18--24       West            Voted
# 3     White     Female  Some college          65+    Midwest            Voted
# 4     White     Female   HS or Below       35--49      South  Did not vote/NA
#
# [5 rows x 241 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4138 entries, 0 to 4137
# Data columns (total 241 columns):
#  #    Column                           Dtype
# ---   ------                           -----
#  0    response_id                      object
#  1    start_date                       datetime64[ns]
#  2    right_track                      category
#  3    economy_better                   category
#  4    interest                         category
#  5    registration                     category
#  6    news_sources_facebook            category
#  7    news_sources_cnn                 category
#  8    news_sources_msnbc               category
#  9    news_sources_fox                 category
#  10   news_sources_network             category
#  11   news_sources_localtv             category
#  12   news_sources_telemundo           category
#  13   news_sources_npr                 category
#  14   news_sources_amtalk              category
#  15   news_sources_new_york_times      category
#  16   news_sources_local_newspaper     category
#  17   news_sources_other               category
#  18   news_sources_other_TEXT          object
#  19   pres_approval                    category
#  20   vote_2016                        category
#  21   vote_2016_other_text             object
#  22   vote_intention_retro             category
#  23   vote_2020_retro                  category
#  24   vote_2020_retro_other_text       object
#  25   who_won                          category
#  26   who_won_other_text               object
#  27   primary_party_retro              category
#  28   group_favorability_whites        category
#  29   group_favorability_blacks        category
#  30   group_favorability_latinos       category
#  31   group_favorability_asians        category
#  32   group_favorability_evangelicals  category
#  33   group_favorability_socialists    category
#  34   group_favorability_muslims       category
#  35   group_favorability_labor_unions  category
#  36   group_favorability_the_police    category
#  37   group_favorability_undocumented  category
#  38   group_favorability_lgbt          category
#  39   group_favorability_republicans   category
#  40   group_favorability_democrats     category
#  41   group_favorability_white_men     category
#  42   group_favorability_jews          category
#  43   group_favorability_blm           category
#  44   group_favorability_trump_s       category
#  45   group_favorability_biden_s       category
#  46   cand_favorability_trump          category
#  47   cand_favorability_obama          category
#  48   cand_favorability_biden          category
#  49   cand_favorability_harris         category
#  50   cand_favorability_pence          category
#  51   rep_prim_vote                    category
#  52   rep_prim_vote_TEXT               object
#  53   dem_prim_vote                    category
#  54   dem_prim_vote_TEXT               object
#  55   house_intent_retro               category
#  56   senate_intent_retro              category
#  57   governor_intent_retro            category
#  58   primary_sen_barrasso             category
#  59   primary_sen_blackburn            category
#  60   primary_sen_blunt                category
#  61   primary_sen_boozman              category
#  62   primary_sen_crapo                category
#  63   primary_sen_cruz                 category
#  64   primary_sen_fischer              category
#  65   primary_sen_grassley             category
#  66   primary_sen_hoeven               category
#  67   primary_sen_lankford             category
#  68   primary_sen_lee                  category
#  69   primary_sen_moran                category
#  70   primary_sen_murkowski            category
#  71   primary_sen_neelykennedy         category
#  72   primary_sen_paul                 category
#  73   primary_sen_portman              category
#  74   primary_sen_rubio                category
#  75   primary_sen_scott_tim            category
#  76   primary_sen_shelby               category
#  77   primary_sen_thune                category
#  78   primary_sen_toomey               category
#  79   primary_sen_wicker               category
#  80   primary_sen_young                category
#  81   primary_sen_braun                category
#  82   primary_sen_cramer               category
#  83   primary_sen_hawley               category
#  84   primary_sen_romney               category
#  85   primary_sen_scott_rick           category
#  86   cand_truth_donald_trump          category
#  87   cand_truth_joe_biden             category
#  88   cand_facts_donald_trump          category
#  89   cand_facts_joe_biden             category
#  90   pence_president                  category
#  91   racial_attitudes_tryhard         category
#  92   racial_attitudes_generations     category
#  93   racial_attitudes_marry           category
#  94   racial_attitudes_date            category
#  95   gender_attitudes_maleboss        category
#  96   gender_attitudes_logical         category
#  97   gender_attitudes_opportunity     category
#  98   gender_attitudes_complain        category
#  99   discrimination_blacks            category
#  100  discrimination_whites            category
#  101  discrimination_muslims           category
#  102  discrimination_christians        category
#  103  discrimination_jews              category
#  104  discrimination_women             category
#  105  discrimination_men               category
#  106  discrimination_asians            category
#  107  discrimination_latinos           category
#  108  sen_knowledge                    category
#  109  sc_knowledge                     category
#  110  pid3                             category
#  111  pid7                             category
#  112  pid7_legacy                      category
#  113  strength_democrat                category
#  114  strength_republican              category
#  115  lean_independent                 category
#  116  ideo5                            category
#  117  employment                       category
#  118  employment_other_text            object
#  119  work_location                    category
#  120  foreign_born                     category
#  121  language                         category
#  122  religion                         category
#  123  religion_other_text              object
#  124  is_evangelical                   category
#  125  orientation_group                category
#  126  in_union                         category
#  127  married                          category
#  128  extra_n_children                 float64
#  129  household_gun_owner              category
#  130  wall                             category
#  131  cap_carbon                       category
#  132  guns_bg                          category
#  133  mctaxes                          category
#  134  estate_tax                       category
#  135  raise_upper_tax                  category
#  136  college                          category
#  137  abortion_any_time                category
#  138  abortion_never                   category
#  139  abortion_conditions              category
#  140  late_term_abortion               category
#  141  abolish_priv_insurance           category
#  142  abortion_insurance               category
#  143  abortion_waiting                 category
#  144  china_tariffs                    category
#  145  criminal_immigration             category
#  146  environment                      category
#  147  guaranteed_jobs                  category
#  148  green_new_deal                   category
#  149  gun_registry                     category
#  150  immigration_insurance            category
#  151  immigration_separation           category
#  152  immigration_system               category
#  153  immigration_wire                 category
#  154  israel                           category
#  155  marijuana                        category
#  156  maternityleave                   category
#  157  medicare_for_all                 category
#  158  military_size                    category
#  159  minwage                          category
#  160  muslimban                        category
#  161  oil_and_gas                      category
#  162  reparations                      category
#  163  right_to_work                    category
#  164  saudi_arabia                     category
#  165  ten_commandments                 category
#  166  trade                            category
#  167  trans_military                   category
#  168  uctaxes2                         category
#  169  vouchers                         category
#  170  gov_insurance                    category
#  171  public_option                    category
#  172  health_subsidies                 category
#  173  path_to_citizenship              category
#  174  dreamers                         category
#  175  deportation                      category
#  176  ban_guns                         category
#  177  ban_assault_rifles               category
#  178  limit_magazines                  category
#  179  impeach_trump                    category
#  180  egypt                            category
#  181  fc_smallgov                      category
#  182  fc_trad_val                      category
#  183  statements_protect_traditions    category
#  184  statements_defense_burden        category
#  185  statements_trade_effects         category
#  186  statements_christianity_assault  category
#  187  statements_gender_identity       category
#  188  statements_american_loss         category
#  189  statements_imm_assimilate        category
#  190  statements_gun_rights            category
#  191  statements_confront_china        category
#  192  statements_foreign_interests     category
#  193  elect_conf_conduct_retro         category
#  194  elect_conf_vote_retro            category
#  195  extra_vote_mail_retr             category
#  196  extra_vacc_flu                   float64
#  197  extra_vacc_covid                 float64
#  198  extra_dem_violence               category
#  199  extra_ind_violence               category
#  200  extra_rep_violence               category
#  201  extra_corona_concern             category
#  202  extra_sick_you                   category
#  203  extra_sick_family                category
#  204  extra_sick_work                  category
#  205  extra_sick_other                 category
#  206  extra_covid_worn_mask            category
#  207  extra_covid_socialize_distance   category
#  208  extra_covid_socialize_no_dist    category
#  209  extra_trump_corona               category
#  210  extra_gub_corona                 category
#  211  extra_covid_cancel_meet          category
#  212  extra_covid_close_business       category
#  213  extra_covid_close_schools        category
#  214  extra_covid_work_home            category
#  215  extra_covid_restrict_home        category
#  216  extra_covid_testing              category
#  217  extra_covid_require_mask         category
#  218  capitol_approval                 category
#  219  capitol_trump_approv             category
#  220  capitol_trump_more               category
#  221  twitter_ban                      category
#  222  age                              int8
#  223  gender                           category
#  224  census_region                    category
#  225  hispanic                         category
#  226  race_ethnicity                   category
#  227  household_income                 category
#  228  education                        category
#  229  state                            object
#  230  congress_district                object
#  231  weight                           float64
#  232  weight_2020                      float64
#  233  weight_both                      float64
#  234  race_lab_nohisp                  object
#  235  race_lab                         object
#  236  gender_lab                       category
#  237  educ_lab                         object
#  238  agegroup_lab                     category
#  239  region_lab                       category
#  240  voted_lab                        object
# dtypes: category(218), datetime64[ns](1), float64(6), int8(1), object(15)
# memory usage: 1.6+ MB

# %%
catvars = ["gender_lab", "race_lab", "educ_lab", "agegroup_lab", "region_lab", "voted_lab"]

for var in catvars:
    _dfyg = (
        df_yougov[var]
        .value_counts(normalize=True)
        .reset_index()
        .rename_column(var, "yougov")
    )
    _dfcps = (
        df_cps[var]
        .value_counts(normalize=True)
        .reset_index()
        .rename_column(var, "cps")
    )
    _dfns = (
        df_ns[var]
        .value_counts(normalize=True)
        .reset_index()
        .rename_column(var, "nscape")
    )    
    _dfsumm = (
        _dfyg
        .merge(_dfcps, on="index", validate="1:1")
        .merge(_dfns, on="index", validate="1:1")
        .round(3)
    )
    
    # reorder agegroup
    if var == "agegroup_lab":
        _dfsumm["index"] = (
            pd.Categorical(
                _dfsumm["index"], categories=agegroup_order, ordered=True)
        )
        _dfsumm = _dfsumm.sort_values("index")
    
    # reorder regions    
    if var == "region_lab":
        _dfsumm["index"] = pd.Categorical(
            _dfsumm["index"], categories=region_order, ordered=True
        )
        _dfsumm = _dfsumm.sort_values("index")
        _dfsumm["index"] = _dfsumm["index"].apply(lambda x: x + " region")
        
    if var=="educ_lab":
#         _dfsumm["ed"]
        _dfsumm.loc[_dfsumm['index'] == 'Postgrad', 'index'] = 'Postgraduate degree'
        _dfsumm.loc[_dfsumm['index'] == 'HS or Below', 'index'] = 'High school or below'
        _dfsumm.loc[_dfsumm['index'] == 'College', 'index'] = 'College degree'

    if var=="voted_lab":
        _dfsumm['cps'] = "---"

#     pandas_to_tex(_dfsumm, f"../tabs/yg_cps_nscape_{var}")
    display(_dfsumm)
# Out:
#     index  yougov   cps  nscape
# 0  Female   0.525  0.52    0.59
# 1    Male   0.475  0.48    0.41
#       index  yougov    cps  nscape
# 0     White   0.635  0.673   0.704
# 1  Hispanic   0.148  0.141   0.124
# 2     Black   0.127  0.099   0.109
# 3     Other   0.049  0.023   0.023
# 4     Asian   0.041  0.064   0.040
#                   index  yougov    cps  nscape
# 0  High school or below   0.362  0.382   0.277
# 1          Some college   0.287  0.267   0.354
# 2        College degree   0.225  0.219   0.248
# 3   Postgraduate degree   0.125  0.132   0.121
#     index  yougov    cps  nscape
# 4  18--24   0.094  0.112   0.111
# 3  25--34   0.177  0.143   0.142
# 0  35--49   0.257  0.240   0.258
# 1  50--64   0.247  0.248   0.319
# 2     65+   0.226  0.257   0.170
#               index  yougov    cps  nscape
# 1       West region   0.202  0.274   0.216
# 2    Midwest region   0.200  0.193   0.246
# 3  Northeast region   0.178  0.161   0.176
# 0      South region   0.421  0.371   0.362
#              index  yougov  cps  nscape
# 0            Voted   0.638  ---   0.772
# 1  Did not vote/NA   0.362  ---   0.228
