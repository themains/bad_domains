# %%
import os
import pandas as pd
import janitor
from IPython.display import display
from inequality.gini import Gini
from scipy.stats import circmean
import warnings

warnings.filterwarnings("ignore")

import numpy as np

FP_IND_DOMAIN = "../data/yg_ind_domain.csv.gz"
FP_VISITS_DATA = "../data/6.3m-ind-domain-data.csv.gz"
FP_VT_LABELS = "../data/yg_virustotal_dat.csv"
FP_IND_DEMO = "../data/profile.csv"
FILEPATHS = [value for name, value in globals().items() if name.startswith("FP_")]
for file_path in FILEPATHS:
    try:
        assert os.path.exists(file_path), f"File not found: {file_path}"
    except AssertionError:
        print(f"File not found: {file_path}.")

# %%
# checking all vt output labels
import json

json_dir = "./payloads_json/"

# Initialize an empty set to collect all unique keys
all_keys = set()

# Loop through each file in the directory
for filename in os.listdir(json_dir):
    if filename.endswith(".json"):
        filepath = os.path.join(json_dir, filename)
        with open(filepath, "r") as f:
            try:
                data = json.load(f)
                stats = data["data"]["attributes"]["last_analysis_stats"]
                all_keys.update(stats.keys())
            except (json.JSONDecodeError, KeyError, TypeError) as e:
                print(f"Skipping {filename}: {e}")

# Output the result
print("All unique keys in last_analysis_stats across all files:")
print(all_keys)
# Out:
# Skipping harris-interactive.fr.json: Unterminated string starting at: line 68 column 22 (char 2398)
# Skipping contactsdirect.com.json: Unterminated string starting at: line 38 column 30 (char 1197)
# Skipping survivalinternational.org.json: Expecting ',' delimiter: line 78 column 13 (char 2623)
# Skipping conservativenewsdaily.net.json: Expecting property name enclosed in double quotes: line 41 column 21 (char 1215)
# Skipping carsformoms.org.json: Expecting ',' delimiter: line 555 column 15 (char 22355)
# Skipping minimalistquotes.com.json: Unterminated string starting at: line 38 column 21 (char 1214)
# Skipping porsche.com.json: Expecting property name enclosed in double quotes: line 280 column 2 (char 11606)
# Skipping westshorehome.com.json: Expecting property name enclosed in double quotes: line 37 column 3 (char 1215)
# Skipping minify.mobi.json: Unterminated string starting at: line 53 column 13 (char 3153)
# Skipping shareowneronline.com.json: Unterminated string starting at: line 85 column 13 (char 4554)
# Skipping rlahre.com.json: Unterminated string starting at: line 93 column 22 (char 3086)
# Skipping fau.edu.json: Expecting property name enclosed in double quotes: line 91 column 12 (char 3157)
# Skipping timeandtidetattoo.com.json: Unterminated string starting at: line 227 column 33 (char 10192)
# Skipping conservativefighters.org.json: Expecting ':' delimiter: line 92 column 27 (char 4564)
# Skipping themntable.com.json: Expecting property name enclosed in double quotes: line 550 column 16 (char 20946)
# Skipping neuroast.com.json: Expecting property name enclosed in double quotes: line 448 column 12 (char 17239)
# Skipping myvidster.com.json: Expecting ',' delimiter: line 112 column 13 (char 4558)
# Skipping boulderlocavore.com.json: Unterminated string starting at: line 75 column 22 (char 2438)
# Skipping legalboulevard.com.json: Expecting property name enclosed in double quotes: line 38 column 6 (char 1215)
# Skipping carshieldprotection.com.json: Expecting value: line 38 column 27 (char 1215)
# Skipping laclrs.org.json: Unterminated string starting at: line 64 column 22 (char 2106)
# Skipping drf.com.json: Unterminated string starting at: line 659 column 21 (char 25420)
# Skipping miniglobalcitizens.com.json: Expecting property name enclosed in double quotes: line 76 column 16 (char 3156)
# Skipping minewig.com.json: Expecting value: line 39 column 19 (char 1215)
# Skipping gunviolencearchive.org.json: Unterminated string starting at: line 75 column 22 (char 2370)
# Skipping parkattour18.com.json: Expecting property name enclosed in double quotes: line 39 column 12 (char 1215)
# Skipping ushmm.org.json: Unterminated string starting at: line 123 column 22 (char 4322)
# Skipping binnys.com.json: Unterminated string starting at: line 90 column 22 (char 3485)
# Skipping pavmhh.com.json: Expecting ',' delimiter: line 111 column 13 (char 4565)
# Skipping videohclips.com.json: Expecting property name enclosed in double quotes: line 39 column 18 (char 1215)
# Skipping editorx.com.json: Expecting property name enclosed in double quotes: line 37 column 12 (char 1215)
# Skipping iga.com.json: Expecting property name enclosed in double quotes: line 39 column 8 (char 1215)
# Skipping t0p0ff3rs.com.json: Unterminated string starting at: line 32 column 22 (char 950)
# Skipping minecraftside.com.json: Expecting property name enclosed in double quotes: line 40 column 6 (char 1215)
# Skipping mugshotlook.com.json: Expecting property name enclosed in double quotes: line 302 column 16 (char 12757)
# Skipping houseoffun.com.json: Unterminated string starting at: line 53 column 22 (char 1673)
# Skipping calniesigndflamin.com.json: Expecting property name enclosed in double quotes: line 328 column 3 (char 13014)
# Skipping dailymatureporn.com.json: Unterminated string starting at: line 39 column 30 (char 1207)
# Skipping pdfsimpli.com.json: Expecting ',' delimiter: line 35 column 1 (char 1215)
# Skipping springbot.com.json: Unterminated string starting at: line 106 column 21 (char 4558)
# Skipping garlicsauce.com.json: Expecting property name enclosed in double quotes: line 471 column 9 (char 18260)
# Skipping survivalfooddeals.com.json: Expecting property name enclosed in double quotes: line 110 column 12 (char 4565)
# Skipping millennial-grind.com.json: Expecting property name enclosed in double quotes: line 97 column 3 (char 3157)
# Skipping eee3368017.com.json: Expecting property name enclosed in double quotes: line 53 column 8 (char 2623)
# Skipping secondchanceboxer.com.json: Unterminated string starting at: line 517 column 31 (char 20942)
# Skipping sebsrec.org.json: Expecting property name enclosed in double quotes: line 39 column 9 (char 1215)
# Skipping megaup.net.json: Expecting property name enclosed in double quotes: line 183 column 20 (char 7254)
# Skipping focosonline.com.json: Unterminated string starting at: line 48 column 22 (char 1537)
# Skipping supernova.com.json: Expecting value: line 87 column 5 (char 2623)
# Skipping bokksu.com.json: Unterminated string starting at: line 93 column 30 (char 3147)
# Skipping chapstick.com.json: Unterminated string starting at: line 78 column 22 (char 2760)
# Skipping govbenefit.org.json: Expecting property name enclosed in double quotes: line 91 column 6 (char 4563)
# Skipping lwv.org.json: Expecting ',' delimiter: line 244 column 42 (char 11477)
# Skipping carthrottle.com.json: Expecting value: line 343 column 35 (char 12881)
# Skipping figpii.com.json: Expecting ',' delimiter: line 619 column 42 (char 23764)
# Skipping myloancare.com.json: Unterminated string starting at: line 69 column 22 (char 2393)
# Skipping revy.io.json: Expecting ',' delimiter: line 96 column 14 (char 3158)
# Skipping deadline.com.json: Expecting property name enclosed in double quotes: line 516 column 8 (char 20947)
# Skipping vivatv.me.json: Unterminated string starting at: line 48 column 22 (char 1534)
# Skipping i-cmg-amlg-prod.appspot.com.json: Expecting ',' delimiter: line 71 column 29 (char 4561)
# Skipping wedovaccines.com.json: Expecting property name enclosed in double quotes: line 589 column 4 (char 23769)
# Skipping rugerforum.net.json: Expecting property name enclosed in double quotes: line 37 column 7 (char 1215)
# Skipping combinatronics.io.json: Unterminated string starting at: line 48 column 22 (char 1532)
# Skipping shoppinggives.com.json: Unterminated string starting at: line 38 column 29 (char 1214)
# Skipping sugarkingdom.io.json: Expecting ':' delimiter: line 38 column 27 (char 1215)
# Skipping ucla.edu.json: Unterminated string starting at: line 88 column 30 (char 3147)
# Skipping riaa.com.json: Expecting property name enclosed in double quotes: line 109 column 5 (char 4564)
# Skipping bobbyrahaltoyota.com.json: Unterminated string starting at: line 184 column 33 (char 7252)
# Skipping callexitfirst.com.json: Expecting property name enclosed in double quotes: line 432 column 18 (char 16854)
# Skipping asseslon.com.json: Unterminated string starting at: line 33 column 22 (char 1034)
# Skipping sipelixirs.com.json: Unterminated string starting at: line 79 column 21 (char 2617)
# Skipping kidrock.com.json: Expecting property name enclosed in double quotes: line 230 column 13 (char 8790)
# Skipping springbokcasino.co.za.json: Unterminated string starting at: line 89 column 21 (char 3156)
# Skipping yourcausegrants.com.json: Expecting property name enclosed in double quotes: line 39 column 12 (char 1215)
# Skipping faderpro.com.json: Unterminated string starting at: line 91 column 30 (char 3144)
# Skipping iris.tv.json: Unterminated string starting at: line 274 column 31 (char 11593)
# Skipping nonbiasedreviews.com.json: Unterminated string starting at: line 224 column 17 (char 8655)
# Skipping lazydogrestaurants.com.json: Expecting property name enclosed in double quotes: line 90 column 13 (char 3153)
# Skipping virtualvocations.com.json: Expecting property name enclosed in double quotes: line 114 column 11 (char 4565)
# Skipping mingomessenger.com.json: Expecting property name enclosed in double quotes: line 39 column 21 (char 1215)
# Skipping columbiagasohio.com.json: Unterminated string starting at: line 65 column 22 (char 2144)
# Skipping prageru.com.json: Expecting ':' delimiter: line 474 column 26 (char 18257)
# Skipping silverbobbin.com.json: Expecting property name enclosed in double quotes: line 645 column 9 (char 25172)
# Skipping minecraften.net.json: Expecting property name enclosed in double quotes: line 37 column 18 (char 1215)
# Skipping minecrafteduservices.com.json: Unterminated string starting at: line 37 column 22 (char 1140)
# Skipping 5280.com.json: Unterminated string starting at: line 83 column 22 (char 2755)
# Skipping myhighperformancecoaching.com.json: Expecting value: line 39 column 29 (char 1215)
# Skipping minim.com.json: Unterminated string starting at: line 32 column 30 (char 1140)
# Skipping celebdirtylaundry.com.json: Expecting ',' delimiter: line 69 column 45 (char 3156)
# Skipping trackyourdividends.com.json: Expecting property name enclosed in double quotes: line 37 column 13 (char 1215)
# Skipping calltothepen.com.json: Expecting property name enclosed in double quotes: line 402 column 18 (char 15446)
# Skipping aeroflot.ru.json: Unterminated string starting at: line 625 column 17 (char 23762)
# Skipping allthatsinteresting.com.json: Expecting property name enclosed in double quotes: line 82 column 10 (char 2623)
# All unique keys in last_analysis_stats across all files:
# {'undetected', 'malicious', 'timeout', 'harmless', 'suspicious'}

# %%
df_vt = (
    pd.read_csv(FP_VT_LABELS)
    .assign(
        malicious_bool=lambda df_: np.where(df_["malicious"] >= 2, True, False),
#         malicious_visits=lambda df_: df_["malicious_bool"] * df_["visits"],
#         malicious_min=lambda df_: df_["malicious_bool"] * df_["duration_min"],
#         malicious_hr=lambda df_: df_["malicious_bool"] * df_["duration_hr"],
        suspicious_bool=lambda df_: df_["suspicious"].astype("bool"),
    ))
df_vt
# Out:
#                    filename  harmless  malicious  suspicious  undetected  \
# 0           teatroporno.com        68          0           0          20
# 1        commissionsoup.com        68          0           0          20
# 2         filesanywhere.com        67          0           0          20
# 3                  lasc.org        67          0           0          20
# 4                 faron.com        67          0           0          21
# ...                     ...       ...        ...         ...         ...
# 64015             givex.com        68          0           0          19
# 64016         diocesemo.org        65          0           0          22
# 64017        karatemart.com        67          0           0          20
# 64018  inthegardenradio.com        66          1           0          21
# 64019     columbiahouse.com        67          0           0          20
#
#        timeout                           forcepoint                    sophos  \
# 0            0                                  sex         sexually explicit
# 1            0          financial data and services                       NaN
# 2            0  personal network storage and backup  personal network storage
# 3            0                                  NaN                       NaN
# 4            0                                  NaN                       NaN
# ...        ...                                  ...                       ...
# 64015        0                                  NaN                       NaN
# 64016        0               widely-known religions                       NaN
# 64017        0                                  NaN                       NaN
# 64018        0                             shopping                       NaN
# 64019        0                                  NaN                       NaN
#
#                 bitdefender         comodo  \
# 0                      porn            NaN
# 1                 financial            NaN
# 2      computersandsoftware            NaN
# 3                       NaN            NaN
# 4                       NaN            NaN
# ...                     ...            ...
# 64015                   NaN            NaN
# 64016             education            NaN
# 64017                   NaN            NaN
# 64018            onlineshop  media sharing
# 64019                   NaN            NaN
#
#                                            alphamnt  malicious_bool  \
# 0                                               NaN           False
# 1                                  Business/Economy           False
# 2      File Sharing/Storage, Information Technology           False
# 3                                  Government/Legal           False
# 4                          Business/Economy, Health           False
# ...                                             ...             ...
# 64015                              Business/Economy           False
# 64016                                      Religion           False
# 64017                             Shopping, Weapons           False
# 64018                                           NaN           False
# 64019                                      Shopping           False
#
#        suspicious_bool
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 64015            False
# 64016            False
# 64017            False
# 64018            False
# 64019            False
#
# [64020 rows x 13 columns]

# %%
df_vt.query("malicious_bool==1")
# Out:
#                      filename  harmless  malicious  suspicious  undetected  \
# 7         spacecloudstore.com        63          2           1          21
# 24             ptistyvymi.com        64          2           0          21
# 143           coreopsisnet.ru        59          7           0          23
# 182              ospotify.com        62          3           1          22
# 325    findpaidfocusgroup.com        66          2           0          19
# ...                       ...       ...        ...         ...         ...
# 63703        ecstaticlane.com        53         11           0          24
# 63750              fmuniv.edu        65          2           0          20
# 63788          crackedmod.com        55         11           0          22
# 63908          downloadph.com        62          2           2          22
# 63973            torodate.com        54         13           0          20
#
#        timeout                forcepoint                    sophos  \
# 7            0                       NaN                       NaN
# 24           0                       NaN                       NaN
# 143          0                       NaN                       NaN
# 182          0                       NaN                       NaN
# 325          0               pay-to-surf                       NaN
# ...        ...                       ...                       ...
# 63703        0                       NaN        phishing and fraud
# 63750        0  educational institutions  educational institutions
# 63788        0                       NaN       spyware and malware
# 63908        0      compromised websites       spyware and malware
# 63973        0                       NaN        phishing and fraud
#
#       bitdefender         comodo  \
# 7          parked            NaN
# 24         parked            NaN
# 143           NaN            NaN
# 182           NaN            NaN
# 325      business  media sharing
# ...           ...            ...
# 63703      parked            NaN
# 63750   education            NaN
# 63788         NaN            NaN
# 63908      parked            NaN
# 63973         NaN            NaN
#
#                                            alphamnt  malicious_bool  \
# 7                                           Unrated            True
# 24                                              NaN            True
# 143                Phishing, Scam/Illegal/Unethical            True
# 182    Email, Productivity Applications, Suspicious            True
# 325                                             NaN            True
# ...                                             ...             ...
# 63703                                      Phishing            True
# 63750                                     Education            True
# 63788                            Hacking, Malicious            True
# 63908                                    Suspicious            True
# 63973                                      Phishing            True
#
#        suspicious_bool
# 7                 True
# 24               False
# 143              False
# 182               True
# 325              False
# ...                ...
# 63703            False
# 63750            False
# 63788            False
# 63908             True
# 63973            False
#
# [1128 rows x 13 columns]

# %%
with open("payloads_json/spacecloudstore.com.json", "r") as f:
    data = json.load(f)
data
# Out:
# {'data': {'attributes': {'last_dns_records': [{'type': 'A',
#      'value': '149.248.3.79',
#      'ttl': 60},
#     {'type': 'NS', 'value': 'ns-240.awsdns-30.com', 'ttl': 21600},
#     {'type': 'NS', 'value': 'ns-1912.awsdns-47.co.uk', 'ttl': 21600},
#     {'type': 'NS', 'value': 'ns-1293.awsdns-33.org', 'ttl': 21600},
#     {'type': 'NS', 'value': 'ns-932.awsdns-52.net', 'ttl': 21600},
#     {'rname': 'awsdns-hostmaster.amazon.com',
#      'retry': 900,
#      'refresh': 7200,
#      'minimum': 86400,
#      'value': 'ns-1293.awsdns-33.org',
#      'expire': 1209600,
#      'ttl': 900,
#      'serial': 1,
#      'type': 'SOA'}],
#    'jarm': '3fd3fd0003fd3fd21c3fd3fd3fd3fdc2ddcfd203d071c45b4b0ffe3d7b4b89',
#    'whois': 'Administrative city: Phoenix\nAdministrative country: United States\nAdministrative email: 49724bce0f18a05bs@privacyguardian.org\nAdministrative state: AZ\nCreate date: 2022-06-02\nDomain name: spacecloudstore.com\nDomain registrar id: 1479\nDomain registrar url: http://www.namesilo.com\nExpiry date: 2023-06-02\nQuery time: 2022-06-05 16:04:51\nRegistrant address: 2883d6c01fb7b343\nRegistrant city: e6a4f84d28ef2f45\nRegistrant company: 503be2a7b0389660\nRegistrant country: United States\nRegistrant email: 49724bce0f18a05bs@privacyguardian.org\nRegistrant fax: 3267309318f7846c\nRegistrant name: a7c224965917ca60\nRegistrant phone: f23d7d806c7e5bbe\nRegistrant state: beff4362a8c1b96d\nRegistrant zip: d61cbc7b9ba3610c\nTechnical city: Phoenix\nTechnical country: United States\nTechnical email: 49724bce0f18a05bs@privacyguardian.org\nTechnical state: AZ\nUpdate date: 2022-06-03',
#    'last_https_certificate_date': 1656484910,
#    'tags': [],
#    'popularity_ranks': {'Statvoo': {'timestamp': 1656694684, 'rank': 36875},
#     'Alexa': {'timestamp': 1656608284, 'rank': 255689},
#     'Cisco Umbrella': {'timestamp': 1656694694, 'rank': 900205}},
#    'last_analysis_date': 1679316310,
#    'last_dns_records_date': 1656484910,
#    'last_analysis_stats': {'harmless': 63,
#     'malicious': 2,
#     'suspicious': 1,
#     'undetected': 21,
#     'timeout': 0},
#    'creation_date': 1654128000,
#    'whois_date': 1685664000,
#    'reputation': 0,
#    'last_analysis_results': {'Bkav': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Bkav'},
#     'CMC Threat Intelligence': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'CMC Threat Intelligence'},
#     'Snort IP sample list': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Snort IP sample list'},
#     '0xSI_f33d': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': '0xSI_f33d'},
#     'ViriBack': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'ViriBack'},
#     'PhishLabs': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'PhishLabs'},
#     'K7AntiVirus': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'K7AntiVirus'},
#     'CINS Army': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'CINS Army'},
#     'Quttera': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Quttera'},
#     'PrecisionSec': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'PrecisionSec'},
#     'OpenPhish': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'OpenPhish'},
#     'VX Vault': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'VX Vault'},
#     'ADMINUSLabs': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'ADMINUSLabs'},
#     'Scantitan': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Scantitan'},
#     'AlienVault': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'AlienVault'},
#     'Sophos': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Sophos'},
#     'Phishtank': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Phishtank'},
#     'ESTsecurity': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'ESTsecurity'},
#     'Spam404': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Spam404'},
#     'SecureBrain': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'SecureBrain'},
#     'CRDF': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'CRDF'},
#     'Fortinet': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Fortinet'},
#     'alphaMountain.ai': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'alphaMountain.ai'},
#     'Lionic': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Lionic'},
#     'Cyble': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Cyble'},
#     'Seclookup': {'category': 'malicious',
#      'result': 'malicious',
#      'method': 'blacklist',
#      'engine_name': 'Seclookup'},
#     'Xcitium Verdict Cloud': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Xcitium Verdict Cloud'},
#     'Google Safebrowsing': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Google Safebrowsing'},
#     'SafeToOpen': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'SafeToOpen'},
#     'ArcSight Threat Intelligence': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'ArcSight Threat Intelligence'},
#     'Cyan': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Cyan'},
#     'Juniper Networks': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Juniper Networks'},
#     'Heimdal Security': {'category': 'malicious',
#      'result': 'malicious',
#      'method': 'blacklist',
#      'engine_name': 'Heimdal Security'},
#     'AutoShun': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'AutoShun'},
#     'Trustwave': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Trustwave'},
#     'AICC (MONITORAPP)': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'AICC (MONITORAPP)'},
#     'CyRadar': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'CyRadar'},
#     'Dr.Web': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Dr.Web'},
#     'Emsisoft': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Emsisoft'},
#     'Abusix': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Abusix'},
#     'Webroot': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Webroot'},
#     'Avira': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Avira'},
#     'securolytics': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'securolytics'},
#     'Antiy-AVL': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Antiy-AVL'},
#     'AlphaSOC': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'AlphaSOC'},
#     'Acronis': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Acronis'},
#     'Quick Heal': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Quick Heal'},
#     'URLQuery': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'URLQuery'},
#     'Viettel Threat Intelligence': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Viettel Threat Intelligence'},
#     'DNS8': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'DNS8'},
#     'benkow.cc': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'benkow.cc'},
#     'EmergingThreats': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'EmergingThreats'},
#     'Chong Lua Dao': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Chong Lua Dao'},
#     'Yandex Safebrowsing': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Yandex Safebrowsing'},
#     'Lumu': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Lumu'},
#     'zvelo': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'zvelo'},
#     'Kaspersky': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Kaspersky'},
#     'Segasec': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Segasec'},
#     'Sucuri SiteCheck': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Sucuri SiteCheck'},
#     'desenmascara.me': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'desenmascara.me'},
#     'CrowdSec': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'CrowdSec'},
#     'Cluster25': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Cluster25'},
#     'URLhaus': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'URLhaus'},
#     'PREBYTES': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'PREBYTES'},
#     'StopForumSpam': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'StopForumSpam'},
#     'Blueliv': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Blueliv'},
#     'Netcraft': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Netcraft'},
#     'ZeroCERT': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'ZeroCERT'},
#     'Phishing Database': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Phishing Database'},
#     'MalwarePatrol': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'MalwarePatrol'},
#     'IPsum': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'IPsum'},
#     'Malwared': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Malwared'},
#     'BitDefender': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'BitDefender'},
#     'GreenSnow': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'GreenSnow'},
#     'G-Data': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'G-Data'},
#     'VIPRE': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'VIPRE'},
#     'SCUMWARE.org': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'SCUMWARE.org'},
#     'PhishFort': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'PhishFort'},
#     'malwares.com URL checker': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'malwares.com URL checker'},
#     'Forcepoint ThreatSeeker': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Forcepoint ThreatSeeker'},
#     'Criminal IP': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Criminal IP'},
#     'Certego': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Certego'},
#     'ESET': {'category': 'suspicious',
#      'result': 'suspicious',
#      'method': 'blacklist',
#      'engine_name': 'ESET'},
#     'Threatsourcing': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Threatsourcing'},
#     'ThreatHive': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'ThreatHive'},
#     'Bfore.Ai PreCrime': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Bfore.Ai PreCrime'}},
#    'last_update_date': 1654214400,
#    'last_modification_date': 1679316326,
#    'tld': 'com',
#    'last_https_certificate': {'public_key': {'rsa': {'key_size': 2048,
#       'modulus': '...',
#       'exponent': '010001'},
#      'algorithm': 'RSA'},
#     'thumbprint_sha256': '789d1040040336f30bce76479421d3dbb66b07da6e5c6d892d7bed6642a02235',
#     'tags': [],
#     'signature_algorithm': 'sha256RSA',
#     'subject': {'CN': 'spacecloudstore.com'},
#     'validity': {'not_after': '2022-08-31 19:54:35',
#      'not_before': '2022-06-02 19:54:36'},
#     'version': 'V3',
#     'extensions': {'certificate_policies': ['2.23.140.1.2.1',
#       '1.3.6.1.4.1.44947.1.1.1'],
#      'extended_key_usage': ['serverAuth', 'clientAuth'],
#      'tags': [],
#      'subject_alternative_name': ['spacecloudstore.com'],
#      'authority_key_identifier': {'keyid': '142eb317b75856cbae500940e61faf9d8b14c2c6'},
#      'ca_information_access': {'CA Issuers': 'http://r3.i.lencr.org/',
#       'OCSP': 'http://r3.o.lencr.org'},
#      'subject_key_identifier': '0f110f158cc99dd32660f66c8bc4ebfaa4873ea5',
#      'key_usage': ['ff'],
#      '1.3.6.1.4.1.11129.2.4.2': '0481f200f00076002979bef09e393921f056739f63a577e5be577d9c600af8f9',
#      'CA': True},
#     'cert_signature': {'signature_algorithm': 'sha256RSA',
#      'signature': '...'},
#     'serial_number': '035481320e1a26461bf4e58ebd56e3d6aacc',
#     'thumbprint': '33b39393f04ee1d96bb8389eb548306d76406f09',
#     'issuer': {'C': 'US', 'CN': 'R3', 'O': "Let's Encrypt"},
#     'size': 1328},
#    'categories': {'alphaMountain.ai': 'Unrated', 'BitDefender': 'parked'},
#    'total_votes': {'harmless': 0, 'malicious': 0}},
#   'type': 'domain',
#   'id': 'spacecloudstore.com',
#   'links': {'self': 'https://www.virustotal.com/api/v3/domains/spacecloudstore.com'}}}

# %%
data
# Out:
# {'data': {'attributes': {'last_dns_records': [{'type': 'A',
#      'value': '149.248.3.79',
#      'ttl': 60},
#     {'type': 'NS', 'value': 'ns-240.awsdns-30.com', 'ttl': 21600},
#     {'type': 'NS', 'value': 'ns-1912.awsdns-47.co.uk', 'ttl': 21600},
#     {'type': 'NS', 'value': 'ns-1293.awsdns-33.org', 'ttl': 21600},
#     {'type': 'NS', 'value': 'ns-932.awsdns-52.net', 'ttl': 21600},
#     {'rname': 'awsdns-hostmaster.amazon.com',
#      'retry': 900,
#      'refresh': 7200,
#      'minimum': 86400,
#      'value': 'ns-1293.awsdns-33.org',
#      'expire': 1209600,
#      'ttl': 900,
#      'serial': 1,
#      'type': 'SOA'}],
#    'jarm': '3fd3fd0003fd3fd21c3fd3fd3fd3fdc2ddcfd203d071c45b4b0ffe3d7b4b89',
#    'whois': 'Administrative city: Phoenix\nAdministrative country: United States\nAdministrative email: 49724bce0f18a05bs@privacyguardian.org\nAdministrative state: AZ\nCreate date: 2022-06-02\nDomain name: spacecloudstore.com\nDomain registrar id: 1479\nDomain registrar url: http://www.namesilo.com\nExpiry date: 2023-06-02\nQuery time: 2022-06-05 16:04:51\nRegistrant address: 2883d6c01fb7b343\nRegistrant city: e6a4f84d28ef2f45\nRegistrant company: 503be2a7b0389660\nRegistrant country: United States\nRegistrant email: 49724bce0f18a05bs@privacyguardian.org\nRegistrant fax: 3267309318f7846c\nRegistrant name: a7c224965917ca60\nRegistrant phone: f23d7d806c7e5bbe\nRegistrant state: beff4362a8c1b96d\nRegistrant zip: d61cbc7b9ba3610c\nTechnical city: Phoenix\nTechnical country: United States\nTechnical email: 49724bce0f18a05bs@privacyguardian.org\nTechnical state: AZ\nUpdate date: 2022-06-03',
#    'last_https_certificate_date': 1656484910,
#    'tags': [],
#    'popularity_ranks': {'Statvoo': {'timestamp': 1656694684, 'rank': 36875},
#     'Alexa': {'timestamp': 1656608284, 'rank': 255689},
#     'Cisco Umbrella': {'timestamp': 1656694694, 'rank': 900205}},
#    'last_analysis_date': 1679316310,
#    'last_dns_records_date': 1656484910,
#    'last_analysis_stats': {'harmless': 63,
#     'malicious': 2,
#     'suspicious': 1,
#     'undetected': 21,
#     'timeout': 0},
#    'creation_date': 1654128000,
#    'whois_date': 1685664000,
#    'reputation': 0,
#    'last_analysis_results': {'Bkav': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Bkav'},
#     'CMC Threat Intelligence': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'CMC Threat Intelligence'},
#     'Snort IP sample list': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Snort IP sample list'},
#     '0xSI_f33d': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': '0xSI_f33d'},
#     'ViriBack': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'ViriBack'},
#     'PhishLabs': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'PhishLabs'},
#     'K7AntiVirus': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'K7AntiVirus'},
#     'CINS Army': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'CINS Army'},
#     'Quttera': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Quttera'},
#     'PrecisionSec': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'PrecisionSec'},
#     'OpenPhish': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'OpenPhish'},
#     'VX Vault': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'VX Vault'},
#     'ADMINUSLabs': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'ADMINUSLabs'},
#     'Scantitan': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Scantitan'},
#     'AlienVault': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'AlienVault'},
#     'Sophos': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Sophos'},
#     'Phishtank': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Phishtank'},
#     'ESTsecurity': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'ESTsecurity'},
#     'Spam404': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Spam404'},
#     'SecureBrain': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'SecureBrain'},
#     'CRDF': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'CRDF'},
#     'Fortinet': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Fortinet'},
#     'alphaMountain.ai': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'alphaMountain.ai'},
#     'Lionic': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Lionic'},
#     'Cyble': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Cyble'},
#     'Seclookup': {'category': 'malicious',
#      'result': 'malicious',
#      'method': 'blacklist',
#      'engine_name': 'Seclookup'},
#     'Xcitium Verdict Cloud': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Xcitium Verdict Cloud'},
#     'Google Safebrowsing': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Google Safebrowsing'},
#     'SafeToOpen': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'SafeToOpen'},
#     'ArcSight Threat Intelligence': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'ArcSight Threat Intelligence'},
#     'Cyan': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Cyan'},
#     'Juniper Networks': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Juniper Networks'},
#     'Heimdal Security': {'category': 'malicious',
#      'result': 'malicious',
#      'method': 'blacklist',
#      'engine_name': 'Heimdal Security'},
#     'AutoShun': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'AutoShun'},
#     'Trustwave': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Trustwave'},
#     'AICC (MONITORAPP)': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'AICC (MONITORAPP)'},
#     'CyRadar': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'CyRadar'},
#     'Dr.Web': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Dr.Web'},
#     'Emsisoft': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Emsisoft'},
#     'Abusix': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Abusix'},
#     'Webroot': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Webroot'},
#     'Avira': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Avira'},
#     'securolytics': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'securolytics'},
#     'Antiy-AVL': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Antiy-AVL'},
#     'AlphaSOC': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'AlphaSOC'},
#     'Acronis': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Acronis'},
#     'Quick Heal': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Quick Heal'},
#     'URLQuery': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'URLQuery'},
#     'Viettel Threat Intelligence': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Viettel Threat Intelligence'},
#     'DNS8': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'DNS8'},
#     'benkow.cc': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'benkow.cc'},
#     'EmergingThreats': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'EmergingThreats'},
#     'Chong Lua Dao': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Chong Lua Dao'},
#     'Yandex Safebrowsing': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Yandex Safebrowsing'},
#     'Lumu': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Lumu'},
#     'zvelo': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'zvelo'},
#     'Kaspersky': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Kaspersky'},
#     'Segasec': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Segasec'},
#     'Sucuri SiteCheck': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Sucuri SiteCheck'},
#     'desenmascara.me': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'desenmascara.me'},
#     'CrowdSec': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'CrowdSec'},
#     'Cluster25': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Cluster25'},
#     'URLhaus': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'URLhaus'},
#     'PREBYTES': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'PREBYTES'},
#     'StopForumSpam': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'StopForumSpam'},
#     'Blueliv': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Blueliv'},
#     'Netcraft': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Netcraft'},
#     'ZeroCERT': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'ZeroCERT'},
#     'Phishing Database': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Phishing Database'},
#     'MalwarePatrol': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'MalwarePatrol'},
#     'IPsum': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'IPsum'},
#     'Malwared': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Malwared'},
#     'BitDefender': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'BitDefender'},
#     'GreenSnow': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'GreenSnow'},
#     'G-Data': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'G-Data'},
#     'VIPRE': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'VIPRE'},
#     'SCUMWARE.org': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'SCUMWARE.org'},
#     'PhishFort': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'PhishFort'},
#     'malwares.com URL checker': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'malwares.com URL checker'},
#     'Forcepoint ThreatSeeker': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Forcepoint ThreatSeeker'},
#     'Criminal IP': {'category': 'undetected',
#      'result': 'unrated',
#      'method': 'blacklist',
#      'engine_name': 'Criminal IP'},
#     'Certego': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Certego'},
#     'ESET': {'category': 'suspicious',
#      'result': 'suspicious',
#      'method': 'blacklist',
#      'engine_name': 'ESET'},
#     'Threatsourcing': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Threatsourcing'},
#     'ThreatHive': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'ThreatHive'},
#     'Bfore.Ai PreCrime': {'category': 'harmless',
#      'result': 'clean',
#      'method': 'blacklist',
#      'engine_name': 'Bfore.Ai PreCrime'}},
#    'last_update_date': 1654214400,
#    'last_modification_date': 1679316326,
#    'tld': 'com',
#    'last_https_certificate': {'public_key': {'rsa': {'key_size': 2048,
#       'modulus': '...',
#       'exponent': '010001'},
#      'algorithm': 'RSA'},
#     'thumbprint_sha256': '789d1040040336f30bce76479421d3dbb66b07da6e5c6d892d7bed6642a02235',
#     'tags': [],
#     'signature_algorithm': 'sha256RSA',
#     'subject': {'CN': 'spacecloudstore.com'},
#     'validity': {'not_after': '2022-08-31 19:54:35',
#      'not_before': '2022-06-02 19:54:36'},
#     'version': 'V3',
#     'extensions': {'certificate_policies': ['2.23.140.1.2.1',
#       '1.3.6.1.4.1.44947.1.1.1'],
#      'extended_key_usage': ['serverAuth', 'clientAuth'],
#      'tags': [],
#      'subject_alternative_name': ['spacecloudstore.com'],
#      'authority_key_identifier': {'keyid': '142eb317b75856cbae500940e61faf9d8b14c2c6'},
#      'ca_information_access': {'CA Issuers': 'http://r3.i.lencr.org/',
#       'OCSP': 'http://r3.o.lencr.org'},
#      'subject_key_identifier': '0f110f158cc99dd32660f66c8bc4ebfaa4873ea5',
#      'key_usage': ['ff'],
#      '1.3.6.1.4.1.11129.2.4.2': '0481f200f00076002979bef09e393921f056739f63a577e5be577d9c600af8f9',
#      'CA': True},
#     'cert_signature': {'signature_algorithm': 'sha256RSA',
#      'signature': '...'},
#     'serial_number': '035481320e1a26461bf4e58ebd56e3d6aacc',
#     'thumbprint': '33b39393f04ee1d96bb8389eb548306d76406f09',
#     'issuer': {'C': 'US', 'CN': 'R3', 'O': "Let's Encrypt"},
#     'size': 1328},
#    'categories': {'alphaMountain.ai': 'Unrated', 'BitDefender': 'parked'},
#    'total_votes': {'harmless': 0, 'malicious': 0}},
#   'type': 'domain',
#   'id': 'spacecloudstore.com',
#   'links': {'self': 'https://www.virustotal.com/api/v3/domains/spacecloudstore.com'}}}

# %%
data.keys()
# Out:
# dict_keys(['data'])

# %%
data["data"].keys()
# Out:
# dict_keys(['attributes', 'type', 'id', 'links'])

# %%
data["data"]["attributes"]
# Out:
# {'last_dns_records': [{'type': 'A', 'value': '149.248.3.79', 'ttl': 60},
#   {'type': 'NS', 'value': 'ns-240.awsdns-30.com', 'ttl': 21600},
#   {'type': 'NS', 'value': 'ns-1912.awsdns-47.co.uk', 'ttl': 21600},
#   {'type': 'NS', 'value': 'ns-1293.awsdns-33.org', 'ttl': 21600},
#   {'type': 'NS', 'value': 'ns-932.awsdns-52.net', 'ttl': 21600},
#   {'rname': 'awsdns-hostmaster.amazon.com',
#    'retry': 900,
#    'refresh': 7200,
#    'minimum': 86400,
#    'value': 'ns-1293.awsdns-33.org',
#    'expire': 1209600,
#    'ttl': 900,
#    'serial': 1,
#    'type': 'SOA'}],
#  'jarm': '3fd3fd0003fd3fd21c3fd3fd3fd3fdc2ddcfd203d071c45b4b0ffe3d7b4b89',
#  'whois': 'Administrative city: Phoenix\nAdministrative country: United States\nAdministrative email: 49724bce0f18a05bs@privacyguardian.org\nAdministrative state: AZ\nCreate date: 2022-06-02\nDomain name: spacecloudstore.com\nDomain registrar id: 1479\nDomain registrar url: http://www.namesilo.com\nExpiry date: 2023-06-02\nQuery time: 2022-06-05 16:04:51\nRegistrant address: 2883d6c01fb7b343\nRegistrant city: e6a4f84d28ef2f45\nRegistrant company: 503be2a7b0389660\nRegistrant country: United States\nRegistrant email: 49724bce0f18a05bs@privacyguardian.org\nRegistrant fax: 3267309318f7846c\nRegistrant name: a7c224965917ca60\nRegistrant phone: f23d7d806c7e5bbe\nRegistrant state: beff4362a8c1b96d\nRegistrant zip: d61cbc7b9ba3610c\nTechnical city: Phoenix\nTechnical country: United States\nTechnical email: 49724bce0f18a05bs@privacyguardian.org\nTechnical state: AZ\nUpdate date: 2022-06-03',
#  'last_https_certificate_date': 1656484910,
#  'tags': [],
#  'popularity_ranks': {'Statvoo': {'timestamp': 1656694684, 'rank': 36875},
#   'Alexa': {'timestamp': 1656608284, 'rank': 255689},
#   'Cisco Umbrella': {'timestamp': 1656694694, 'rank': 900205}},
#  'last_analysis_date': 1679316310,
#  'last_dns_records_date': 1656484910,
#  'last_analysis_stats': {'harmless': 63,
#   'malicious': 2,
#   'suspicious': 1,
#   'undetected': 21,
#   'timeout': 0},
#  'creation_date': 1654128000,
#  'whois_date': 1685664000,
#  'reputation': 0,
#  'last_analysis_results': {'Bkav': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'Bkav'},
#   'CMC Threat Intelligence': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'CMC Threat Intelligence'},
#   'Snort IP sample list': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Snort IP sample list'},
#   '0xSI_f33d': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': '0xSI_f33d'},
#   'ViriBack': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'ViriBack'},
#   'PhishLabs': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'PhishLabs'},
#   'K7AntiVirus': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'K7AntiVirus'},
#   'CINS Army': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'CINS Army'},
#   'Quttera': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Quttera'},
#   'PrecisionSec': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'PrecisionSec'},
#   'OpenPhish': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'OpenPhish'},
#   'VX Vault': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'VX Vault'},
#   'ADMINUSLabs': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'ADMINUSLabs'},
#   'Scantitan': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Scantitan'},
#   'AlienVault': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'AlienVault'},
#   'Sophos': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Sophos'},
#   'Phishtank': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Phishtank'},
#   'ESTsecurity': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'ESTsecurity'},
#   'Spam404': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Spam404'},
#   'SecureBrain': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'SecureBrain'},
#   'CRDF': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'CRDF'},
#   'Fortinet': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Fortinet'},
#   'alphaMountain.ai': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'alphaMountain.ai'},
#   'Lionic': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Lionic'},
#   'Cyble': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Cyble'},
#   'Seclookup': {'category': 'malicious',
#    'result': 'malicious',
#    'method': 'blacklist',
#    'engine_name': 'Seclookup'},
#   'Xcitium Verdict Cloud': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'Xcitium Verdict Cloud'},
#   'Google Safebrowsing': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Google Safebrowsing'},
#   'SafeToOpen': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'SafeToOpen'},
#   'ArcSight Threat Intelligence': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'ArcSight Threat Intelligence'},
#   'Cyan': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'Cyan'},
#   'Juniper Networks': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Juniper Networks'},
#   'Heimdal Security': {'category': 'malicious',
#    'result': 'malicious',
#    'method': 'blacklist',
#    'engine_name': 'Heimdal Security'},
#   'AutoShun': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'AutoShun'},
#   'Trustwave': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Trustwave'},
#   'AICC (MONITORAPP)': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'AICC (MONITORAPP)'},
#   'CyRadar': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'CyRadar'},
#   'Dr.Web': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Dr.Web'},
#   'Emsisoft': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Emsisoft'},
#   'Abusix': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Abusix'},
#   'Webroot': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Webroot'},
#   'Avira': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Avira'},
#   'securolytics': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'securolytics'},
#   'Antiy-AVL': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Antiy-AVL'},
#   'AlphaSOC': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'AlphaSOC'},
#   'Acronis': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Acronis'},
#   'Quick Heal': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Quick Heal'},
#   'URLQuery': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'URLQuery'},
#   'Viettel Threat Intelligence': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Viettel Threat Intelligence'},
#   'DNS8': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'DNS8'},
#   'benkow.cc': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'benkow.cc'},
#   'EmergingThreats': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'EmergingThreats'},
#   'Chong Lua Dao': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Chong Lua Dao'},
#   'Yandex Safebrowsing': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Yandex Safebrowsing'},
#   'Lumu': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'Lumu'},
#   'zvelo': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'zvelo'},
#   'Kaspersky': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Kaspersky'},
#   'Segasec': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'Segasec'},
#   'Sucuri SiteCheck': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Sucuri SiteCheck'},
#   'desenmascara.me': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'desenmascara.me'},
#   'CrowdSec': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'CrowdSec'},
#   'Cluster25': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'Cluster25'},
#   'URLhaus': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'URLhaus'},
#   'PREBYTES': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'PREBYTES'},
#   'StopForumSpam': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'StopForumSpam'},
#   'Blueliv': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Blueliv'},
#   'Netcraft': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'Netcraft'},
#   'ZeroCERT': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'ZeroCERT'},
#   'Phishing Database': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Phishing Database'},
#   'MalwarePatrol': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'MalwarePatrol'},
#   'IPsum': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'IPsum'},
#   'Malwared': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Malwared'},
#   'BitDefender': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'BitDefender'},
#   'GreenSnow': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'GreenSnow'},
#   'G-Data': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'G-Data'},
#   'VIPRE': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'VIPRE'},
#   'SCUMWARE.org': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'SCUMWARE.org'},
#   'PhishFort': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'PhishFort'},
#   'malwares.com URL checker': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'malwares.com URL checker'},
#   'Forcepoint ThreatSeeker': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'Forcepoint ThreatSeeker'},
#   'Criminal IP': {'category': 'undetected',
#    'result': 'unrated',
#    'method': 'blacklist',
#    'engine_name': 'Criminal IP'},
#   'Certego': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Certego'},
#   'ESET': {'category': 'suspicious',
#    'result': 'suspicious',
#    'method': 'blacklist',
#    'engine_name': 'ESET'},
#   'Threatsourcing': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Threatsourcing'},
#   'ThreatHive': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'ThreatHive'},
#   'Bfore.Ai PreCrime': {'category': 'harmless',
#    'result': 'clean',
#    'method': 'blacklist',
#    'engine_name': 'Bfore.Ai PreCrime'}},
#  'last_update_date': 1654214400,
#  'last_modification_date': 1679316326,
#  'tld': 'com',
#  'last_https_certificate': {'public_key': {'rsa': {'key_size': 2048,
#     'modulus': '...',
#     'exponent': '010001'},
#    'algorithm': 'RSA'},
#   'thumbprint_sha256': '789d1040040336f30bce76479421d3dbb66b07da6e5c6d892d7bed6642a02235',
#   'tags': [],
#   'signature_algorithm': 'sha256RSA',
#   'subject': {'CN': 'spacecloudstore.com'},
#   'validity': {'not_after': '2022-08-31 19:54:35',
#    'not_before': '2022-06-02 19:54:36'},
#   'version': 'V3',
#   'extensions': {'certificate_policies': ['2.23.140.1.2.1',
#     '1.3.6.1.4.1.44947.1.1.1'],
#    'extended_key_usage': ['serverAuth', 'clientAuth'],
#    'tags': [],
#    'subject_alternative_name': ['spacecloudstore.com'],
#    'authority_key_identifier': {'keyid': '142eb317b75856cbae500940e61faf9d8b14c2c6'},
#    'ca_information_access': {'CA Issuers': 'http://r3.i.lencr.org/',
#     'OCSP': 'http://r3.o.lencr.org'},
#    'subject_key_identifier': '0f110f158cc99dd32660f66c8bc4ebfaa4873ea5',
#    'key_usage': ['ff'],
#    '1.3.6.1.4.1.11129.2.4.2': '0481f200f00076002979bef09e393921f056739f63a577e5be577d9c600af8f9',
#    'CA': True},
#   'cert_signature': {'signature_algorithm': 'sha256RSA',
#    'signature': '...'},
#   'serial_number': '035481320e1a26461bf4e58ebd56e3d6aacc',
#   'thumbprint': '33b39393f04ee1d96bb8389eb548306d76406f09',
#   'issuer': {'C': 'US', 'CN': 'R3', 'O': "Let's Encrypt"},
#   'size': 1328},
#  'categories': {'alphaMountain.ai': 'Unrated', 'BitDefender': 'parked'},
#  'total_votes': {'harmless': 0, 'malicious': 0}}

# %%
data["data"]["attributes"]["last_analysis_results"]
# Out:
# {'Bkav': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'Bkav'},
#  'CMC Threat Intelligence': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'CMC Threat Intelligence'},
#  'Snort IP sample list': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Snort IP sample list'},
#  '0xSI_f33d': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': '0xSI_f33d'},
#  'ViriBack': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'ViriBack'},
#  'PhishLabs': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'PhishLabs'},
#  'K7AntiVirus': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'K7AntiVirus'},
#  'CINS Army': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'CINS Army'},
#  'Quttera': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Quttera'},
#  'PrecisionSec': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'PrecisionSec'},
#  'OpenPhish': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'OpenPhish'},
#  'VX Vault': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'VX Vault'},
#  'ADMINUSLabs': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'ADMINUSLabs'},
#  'Scantitan': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Scantitan'},
#  'AlienVault': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'AlienVault'},
#  'Sophos': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Sophos'},
#  'Phishtank': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Phishtank'},
#  'ESTsecurity': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'ESTsecurity'},
#  'Spam404': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Spam404'},
#  'SecureBrain': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'SecureBrain'},
#  'CRDF': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'CRDF'},
#  'Fortinet': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Fortinet'},
#  'alphaMountain.ai': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'alphaMountain.ai'},
#  'Lionic': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Lionic'},
#  'Cyble': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Cyble'},
#  'Seclookup': {'category': 'malicious',
#   'result': 'malicious',
#   'method': 'blacklist',
#   'engine_name': 'Seclookup'},
#  'Xcitium Verdict Cloud': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'Xcitium Verdict Cloud'},
#  'Google Safebrowsing': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Google Safebrowsing'},
#  'SafeToOpen': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'SafeToOpen'},
#  'ArcSight Threat Intelligence': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'ArcSight Threat Intelligence'},
#  'Cyan': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'Cyan'},
#  'Juniper Networks': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Juniper Networks'},
#  'Heimdal Security': {'category': 'malicious',
#   'result': 'malicious',
#   'method': 'blacklist',
#   'engine_name': 'Heimdal Security'},
#  'AutoShun': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'AutoShun'},
#  'Trustwave': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Trustwave'},
#  'AICC (MONITORAPP)': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'AICC (MONITORAPP)'},
#  'CyRadar': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'CyRadar'},
#  'Dr.Web': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Dr.Web'},
#  'Emsisoft': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Emsisoft'},
#  'Abusix': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Abusix'},
#  'Webroot': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Webroot'},
#  'Avira': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Avira'},
#  'securolytics': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'securolytics'},
#  'Antiy-AVL': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Antiy-AVL'},
#  'AlphaSOC': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'AlphaSOC'},
#  'Acronis': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Acronis'},
#  'Quick Heal': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Quick Heal'},
#  'URLQuery': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'URLQuery'},
#  'Viettel Threat Intelligence': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Viettel Threat Intelligence'},
#  'DNS8': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'DNS8'},
#  'benkow.cc': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'benkow.cc'},
#  'EmergingThreats': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'EmergingThreats'},
#  'Chong Lua Dao': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Chong Lua Dao'},
#  'Yandex Safebrowsing': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Yandex Safebrowsing'},
#  'Lumu': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'Lumu'},
#  'zvelo': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'zvelo'},
#  'Kaspersky': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Kaspersky'},
#  'Segasec': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'Segasec'},
#  'Sucuri SiteCheck': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Sucuri SiteCheck'},
#  'desenmascara.me': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'desenmascara.me'},
#  'CrowdSec': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'CrowdSec'},
#  'Cluster25': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'Cluster25'},
#  'URLhaus': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'URLhaus'},
#  'PREBYTES': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'PREBYTES'},
#  'StopForumSpam': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'StopForumSpam'},
#  'Blueliv': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Blueliv'},
#  'Netcraft': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'Netcraft'},
#  'ZeroCERT': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'ZeroCERT'},
#  'Phishing Database': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Phishing Database'},
#  'MalwarePatrol': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'MalwarePatrol'},
#  'IPsum': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'IPsum'},
#  'Malwared': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Malwared'},
#  'BitDefender': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'BitDefender'},
#  'GreenSnow': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'GreenSnow'},
#  'G-Data': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'G-Data'},
#  'VIPRE': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'VIPRE'},
#  'SCUMWARE.org': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'SCUMWARE.org'},
#  'PhishFort': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'PhishFort'},
#  'malwares.com URL checker': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'malwares.com URL checker'},
#  'Forcepoint ThreatSeeker': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'Forcepoint ThreatSeeker'},
#  'Criminal IP': {'category': 'undetected',
#   'result': 'unrated',
#   'method': 'blacklist',
#   'engine_name': 'Criminal IP'},
#  'Certego': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Certego'},
#  'ESET': {'category': 'suspicious',
#   'result': 'suspicious',
#   'method': 'blacklist',
#   'engine_name': 'ESET'},
#  'Threatsourcing': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Threatsourcing'},
#  'ThreatHive': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'ThreatHive'},
#  'Bfore.Ai PreCrime': {'category': 'harmless',
#   'result': 'clean',
#   'method': 'blacklist',
#   'engine_name': 'Bfore.Ai PreCrime'}}

# %%
data["data"]["attributes"]["last_analysis_stats"]
# Out:
# {'harmless': 63,
#  'malicious': 2,
#  'suspicious': 1,
#  'undetected': 21,
#  'timeout': 0}
